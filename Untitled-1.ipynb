# %%
import obspy

st = obspy.read("D:/temp/z22020_07_23_09h03m21s_Meter1000060.mseed")

print(st)
# Out:
# 1 Trace(s) in Stream:
# ZI.T0006..HS1 | 2020-07-23T09:03:21.000000Z - 2020-08-14T17:33:20.980000Z | 50.0 Hz, 96570000 samples

# %%
#plot st
st.plot()
